# %%
from flask import Flask

app = Flask(__name__)

@app.route("/")
def hello_world():
    return "<p>Hello, World!</p>"

# %%
# !flask --app aa run
#  * Serving Flask app 'hello'
#  * Running on http://127.0.0.1:5000 (Press CTRL+C to quit)
# Out:
# Usage: flask run [OPTIONS]
# Try 'flask run --help' for help.
#
# Error: Could not import 'aa'.
